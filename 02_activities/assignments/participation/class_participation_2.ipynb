# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy
import PIL 
import requests

# %%
np.random.seed(613)
x = np.arange(50)
y1 = np.random.randint(0,100,50)
y2 = np.random.randint(0,100,50)

# %%
fig, ax = plt.subplots(figsize=(5,3))
ax.plot(x,y1, label= "Person 1")
ax.plot(x,y2, label= "Person 2")
ax.legend(loc="lower right",
          frameon = True,
          fontsize = 12,
          ncol = 2,
          shadow = True)

# %%
fig, ax = plt.subplots(figsize=(5,3))
ax.plot(x,y1, label= "Person 1")
ax.plot(x,y2, label= "Person 2")
ax.legend(loc="upper left",
          bbox_to_anchor=(1,1))

# %%
fig, ax = plt.subplots(figsize=(5,3))
ax.scatter(x,y1, label="Person 1")
ax.scatter(x,y2, label="person 2")
ax.legend(loc = 'lower right')
ax.text(10,95,"ciara says it's important")
# Out:
# Text(10, 95, "ciara says it's important")

# %%
fig, ax = plt.subplots(figsize=(5,3))
ax.scatter(x,y1, label="Person 1")
ax.scatter(x,y2, label="person 2")
ax.legend(loc = 'lower right')
ax.text(10,95,"ciara says it's important",
        ha = 'center',
        color='red',
        size = 20)
# Out:
# Text(10, 95, "ciara says it's important")

# %%
fig, ax = plt.subplots()
ax.axis([0,10,0,10])

ax.text(1,5, "Data:(1,5)", transform = ax.transData)
ax.text(0.5, 0.1, "Axes:(0.5,0.1)", transform = ax.transAxes)
ax.text(0.2, 0.2, "Figure:(0.2,0.2)", transform = fig.transFigure)
# Out:
# Text(0.2, 0.2, 'Figure:(0.2,0.2)')

# %%
# fig, ax = plt.subplots(figsize=(5,3))
# ax.scatter(x,y1, label = "person 1")
# ax.scatter(x,y2, label = "person 2")
# ax.legend(loc="lower right")

# ax.annotate("this is important!", xy=(10,95),
#             aytext=(20,94), arrowprops = dict(facecolor = 'black'))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[18], line 6
#       3 ax.scatter(x,y2, label = "person 2")
#       4 ax.legend(loc="lower right")
# ----> 6 ax.annotate("this is important!", xy=(10,95),
#       7             aytext=(20,94), arrowprops = dict(facecolor = 'black'))
#
# File /opt/anaconda3/lib/python3.13/site-packages/matplotlib/axes/_axes.py:721, in Axes.annotate(self, text, xy, xytext, xycoords, textcoords, arrowprops, annotation_clip, **kwargs)
#     716 @_docstring.interpd
#     717 def annotate(self, text, xy, xytext=None, xycoords='data', textcoords=None,
#     718              arrowprops=None, annotation_clip=None, **kwargs):
#     719     # Signature must match Annotation. This is verified in
#     720     # test_annotate_signature().
# --> 721     a = mtext.Annotation(text, xy, xytext=xytext, xycoords=xycoords,
#     722                          textcoords=textcoords, arrowprops=arrowprops,
#     723                          annotation_clip=annotation_clip, **kwargs)
#     724     a.set_transform(mtransforms.IdentityTransform())
#     725     if kwargs.get('clip_on', False) and a.get_clip_path() is None:
#
# File /opt/anaconda3/lib/python3.13/site-packages/matplotlib/text.py:1857, in Annotation.__init__(self, text, xy, xytext, xycoords, textcoords, arrowprops, annotation_clip, **kwargs)
#    1854     self.arrow_patch = None
#    1856 # Must come last, as some kwargs may be propagated to arrow_patch.
# -> 1857 Text.__init__(self, x, y, text, **kwargs)
#
# File /opt/anaconda3/lib/python3.13/site-packages/matplotlib/text.py:155, in Text.__init__(self, x, y, text, color, verticalalignment, horizontalalignment, multialignment, fontproperties, rotation, linespacing, rotation_mode, usetex, wrap, transform_rotates_text, parse_math, antialiased, **kwargs)
#     138 self._text = ''
#     139 self._reset_visual_defaults(
#     140     text=text,
#     141     color=color,
#    (...)
#     153     antialiased=antialiased
#     154 )
# --> 155 self.update(kwargs)
#
# File /opt/anaconda3/lib/python3.13/site-packages/matplotlib/text.py:205, in Text.update(self, kwargs)
#     203 # Update bbox last, as it depends on font properties.
#     204 bbox = kwargs.pop("bbox", sentinel)
# --> 205 ret.extend(super().update(kwargs))
#     206 if bbox is not sentinel:
#     207     ret.append(self.set_bbox(bbox))
#
# File /opt/anaconda3/lib/python3.13/site-packages/matplotlib/artist.py:1223, in Artist.update(self, props)
#    1215 def update(self, props):
#    1216     """
#    1217     Update this artist's properties from the dict *props*.
#    1218
#    (...)
#    1221     props : dict
#    1222     """
# -> 1223     return self._update_props(
#    1224         props, "{cls.__name__!r} object has no property {prop_name!r}")
#
# File /opt/anaconda3/lib/python3.13/site-packages/matplotlib/artist.py:1206, in Artist._update_props(self, props, errfmt)
#    1204             func = getattr(self, f"set_{k}", None)
#    1205             if not callable(func):
# -> 1206                 raise AttributeError(
#    1207                     errfmt.format(cls=type(self), prop_name=k),
#    1208                     name=k)
#    1209             ret.append(func(v))
#    1210 if ret:
#
# AttributeError: 'Annotation' object has no property 'aytext'

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.scatter(x,y1)
# ax.scatter(x,y2, label = "Person 2")
# ax.legend(loc='lower right')
ax.yaxis.set_major_locator(plt.NullLocator()) 
ax.xaxis.set_major_formatter(plt.NullFormatter())

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.scatter(x,y1)
ax.xaxis.set_major_locator(plt.MaxNLocator(3))
20
# Out:
# 20

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.scatter(x,y1)

ax.xaxis.set_major_locator(plt.MultipleLocator(5))

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.scatter(x,y1)

plt.xticks(rotation=45, ha='right')
# Out:
# (array([-10.,   0.,  10.,  20.,  30.,  40.,  50.,  60.]),
#  [Text(-10.0, 0, '−10'),
#   Text(0.0, 0, '0'),
#   Text(10.0, 0, '10'),
#   Text(20.0, 0, '20'),
#   Text(30.0, 0, '30'),
#   Text(40.0, 0, '40'),
#   Text(50.0, 0, '50'),
#   Text(60.0, 0, '60')])

# %%
fig, ax = plt.subplots(figsize=(5,3))
ax.plot(x,y1, label= "Person 1")
ax.plot(x,y2, label= "Person 2")
font1 = {'family':'sans serif','color':'indigo','size':20}
plt.xlabel("Shiny New X Axis", fontdict=font1)
# Out:
# Text(0.5, 0, 'Shiny New X Axis')

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'petroff10',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use('fivethirtyeight')

fig, ax = plt.subplots(figsize=(5, 3))
ax.scatter(x,y1)

# %%
np.random.seed(613)
x1 = np.arange(50)
y1 = np.random.randint(0, 75,50)
x2 = np.array(["Luffy", "Zoro", "Nami", "Usopp", "Sanji"])
y2 = np.array([110, 180, 240, 99, 220])

# %%
fig, ax = plt.subplots(figsize=(5, 3))

# %%
plt.style.use('default')

# %%
fig,(ax1, ax2) = plt.subplots(ncols=2,
                        nrows=1,
                        figsize=(7, 3))
ax1.scatter(x1,y1)
plt.xticks(rotation=45, ha='right')
ax2.bar(x2,y2, color="red")
fig.show()
# Out:
# /var/folders/p7/1dpnjx4d1b11kv_dtzk6yyyw0000gn/T/ipykernel_18317/2456658239.py:7: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
fig, someaxes = plt.subplot_mosaic([['ax1', 'ax3'],
                                ['ax2', 'ax3']],
                                figsize=(7, 4))

# %%
fig, someaxes = plt.subplot_mosaic([['ax1', 'ax3'],
                                ['ax2', 'ax3']],
                                figsize=(7, 4))
someaxes["ax1"].scatter(x1,y1)
someaxes["ax2"].bar(x2,y2)
someaxes["ax3"].plot(x1,y1)

plt.show()

# %%
fig, someaxes = plt.subplot_mosaic([['ax1', 'ax3'],
                                ['ax2', 'ax3']],
                                figsize=(7, 4),
                                layout='constrained') 
someaxes["ax1"].scatter(x1,y1)
someaxes["ax2"].bar(x2,y2)
someaxes["ax3"].plot(x1,y1)
someaxes["ax1"].set_xlabel('A Big Label',fontsize=18)
someaxes["ax2"].set_xlabel('Another Label',fontsize=18)
someaxes["ax3"].set_xlabel('Label 2: 2 Fast 2 Furious',fontsize=18 )
# Out:
# Text(0.5, 0, 'Label 2: 2 Fast 2 Furious')

# %%
# first make our sample data
x = np.array(["Luffy", "Zoro", "Nami", "Usopp", "Sanji"])
y1 = np.array([110, 180, 240, 99, 220])
y2 = np.array([170, 100, 90, 120, 50])
# define our figure and axes (just one this time)
fig, ax = plt.subplots(figsize=(7, 3))
# now call both bar and plot elements to the same axes (ax)
ax.bar(x, y1,
color = "indigo")
ax.plot(x, y2,
color = "red")

# %%
y2_sd = np.std(y2)
fig, ax = plt.subplots(figsize=(7, 3))
ax.plot(x, y2, color = "red")
